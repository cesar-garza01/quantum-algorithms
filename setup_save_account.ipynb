# %%
from qiskit_ibm_runtime import QiskitRuntimeService
 
# README FIRST: UPDATE WITH YOUR TOKEN ID FIRST BEFORE RUNNING ANY CODE. TOKEN CAN BE FOUND IN YOUR ACCOUNT DETAILS ON THE IBM QUANTUM PLATFORM
token = "--insert personal token here--"

#Save an IBM Quantum account and set it as your default account.
QiskitRuntimeService.save_account(channel="ibm_cloud", instance = "Cesar Garza", token=token, set_as_default=True, overwrite=True)
